# %% [markdown]
# # NYC EV Fleet Station Network
#
# | | |
# |---|---|
# | **Source** | Department of Citywide Administrative Services (DCAS) |
# | **URL** | [data.cityofnewyork.us](https://data.cityofnewyork.us/City-Government/NYC-EV-Fleet-Station-Network/fc53-9hrv) |
# | **Granularity** | One row per charging station |
# | **Data collection** | DCAS-operated stations via ChargePoint; non-DCAS data from the respective operating agencies |
#
# DCAS operates over 1,025 EV charging stations with 1,600+ ports across city garages and parking facilities, including 180+ fast-charging stations and 80+ solar carports. A subset of stations is open to the public for a nominal fee. NYC DOT separately operates a curbside public charging network.
#
# ## Column Reference
#
# | Column | Description | Notes |
# |---|---|---|
# | `agency` | Abbreviation of the city agency where the station is located | See [Agency Codes](#agency-codes) below |
# | `station_name` | Name of the EV charging station | |
# | `type_of_charger` | Charger type at the station | See [Charger types](#charger-types) below |
# | `no_of_ports` | Number of charging ports at the station | |
# | `public_charger_` | Whether the station accepts public users | See [Public charging](#public-charging) |
# | `fee_for_city_drivers` | Whether city fleet drivers pay a fee | Blank = no fee |
# | `street` | Street address of the station | |
# | `city` | City of the station's location | |
# | `postcode` | ZIP code of the station's location | |
# | `borough` | NYC borough of the station's location | |
#
# ### Geocoded Columns
#
# The following columns were generated by the NYC Open Data team (Office of Technology and Innovation) through geocoding and are not self-reported by DCAS.
#
# | Column | Description |
# |---|---|
# | `latitude` / `longitude` | WGS84 coordinates of the station address |
# | `community_district` | One of 59 community districts used for municipal service delivery |
# | `council_district` | One of 51 NYC City Council districts |
# | `bin` | 7-digit Building Identification Number assigned by DCP; first digit encodes the borough |
# | `bbl` | Borough–Block–Lot identifier assigned by DOF, used for tax and land use purposes |
# | `census_tract` | 2020 census tract; note that leading/trailing zeros are dropped |
# | `nta` | Neighborhood Tabulation Area (NTA) (2020); DCP-defined small area (~15,000 min. population); boundaries do not definitively represent neighborhoods |
#
# ### Agency Codes
#
# | Code | Agency |
# |---|---|
# | ACS | Administration for Children's Services |
# | CITYHALL | City Hall |
# | DCAS | Department of Citywide Administrative Services |
# | DDC | Department of Design & Construction |
# | DEP | Department of Environmental Protection |
# | DHS | Department of Homeless Services |
# | DOC | Department of Correction |
# | DOE | Department of Education |
# | DOH | Department of Health & Mental Hygiene |
# | DOT | Department of Transportation |
# | DPR | Department of Parks & Recreation |
# | DSNY | Department of Sanitation |
# | FDNY | Fire Department of New York |
# | HPD | Housing Preservation & Development |
# | HRA | Human Resources Administration |
# | NYCEM | Office of Emergency Management |
# | NYCHA | New York City Housing Authority |
# | NYPD | New York Police Department |
# | OCME | Office of Chief Medical Examiner |
# | PROB | Department of Probation |
# | TLC | Taxi & Limousine Commission |
#
# ### Charger types
#
# DOT chargers are DOT public chargers available for City fleet use. DOT Flo chargers are curbside public chargers available for City fleet use. The following values indicate the type of charger at the station:
#
# - `DOT Municipal Level 2`
# - `DOT Municipal Level 3`
# - `EV Solar Arc`
# - `EV Solar Canopy`
# - `L2 DOT Flo Curbside`
# - `Level 2`
# - `Level 3 Fast Charger`
# - `Mobile Charger`
#
# ### Public charging
#
# Blank values indicate that the station is not publicly available. City Hall Charging is only available for employees working at City Hall. The following values indicate that the station is open to public users:
#
# - `Yes`
# - `No`
# - `City Hall Charging`
# - `DOT Municipal Parking`
# - `NYC DC Fast Public Charging`
# - `Solar Carport Charging`
# - `*adapter required`

# %% [markdown]
# ## Data Acquisition

# %%
from datetime import date
from pathlib import Path
import json
import requests
import folium
import pandas as pd
import geopandas as gpd
import hashlib

# %%
ROOT = Path("..").resolve()
URL = "https://data.cityofnewyork.us/resource/fc53-9hrv"
PARAMS = {"$limit": 10000}
CSV_PATH = ROOT / "data/raw/dcas_ev_stations.csv"
META_PATH = ROOT / "data/raw/dcas_ev_stations.csv.meta.json"

if CSV_PATH.exists():
    print(f"Already fetched → {CSV_PATH}, skipping.")
else:
    CSV_PATH.parent.mkdir(parents=True, exist_ok=True)
    print(f"Fetching dataset → {CSV_PATH}")
    resp = requests.get(f"{URL}.csv", params=PARAMS, timeout=30)
    resp.raise_for_status()
    CSV_PATH.write_bytes(resp.content)
    META_PATH.write_text(
        json.dumps(
            {
                "fetched_date": str(date.today()),
                "source_url": URL,
                "source_params": PARAMS,
                "row_count": len(resp.text.splitlines()) - 1,
            },
            indent=2,
        )
    )
    print(f"Saved {CSV_PATH.name} ({META_PATH.read_text()})")

pd.read_csv(CSV_PATH)
# Out:
# Already fetched → /home/henrique/source/repos/agentwin-dataset/data/raw/dcas_ev_stations.csv, skipping.
#         agency                 station_name       type_of_charger  \
# 0          ACS  NYC FLEET / ACS_LINDEN_1_L3  Level 3 Fast Charger
# 1          ACS  NYC FLEET / ACS_LINDEN_2_L3  Level 3 Fast Charger
# 2          ACS     NYC FLEET / ACS_LINDEN-1       Level 2 Charger
# 3          ACS    NYC FLEET / ACSSTMARKSPL1       Level 2 Charger
# 4     CITYHALL    NYC FLEET / CITYHALL EAST       Level 2 Charger
# ...        ...                          ...                   ...
# 1680      DCAS         DCAS_BXHOJ-FORDPRO-1       Level 2 Charger
# 1681       DEP    NYC FLEET / DEP_SHAFT18-5       Level 2 Charger
# 1682       DOT  NYC FLEET / DOT_FLTBSH_2_L3  Level 3 Fast Charger
# 1683       DEP    NYC FLEET / DEP_SHAFT18-6       Level 2 Charger
# 1684      DSNY      NYC FLEET / DSNY_BK03-1       Level 2 Charger
#
#       no_of_ports                street           city  postcode  \
# 0             1.0      2554 Linden Blvd  East New York   11208.0
# 1             1.0      2554 Linden Blvd  East New York   11208.0
# 2             1.0      2554 Linden Blvd       Brooklyn   11208.0
# 3             1.0       350 St Marks Pl  Staten Island   10301.0
# 4             2.0    New York City Hall       New York   10007.0
# ...           ...                   ...            ...       ...
# 1680          1.0        265 E 161st St          Bronx   10451.0
# 1681          2.0        20 Westlake Dr       Valhalla   10595.0
# 1682          1.0  2900 Flatbush Avenue       Brooklyn   11234.0
# 1683          2.0        20 Westlake Dr       Valhalla   10595.0
# 1684          2.0       559 Park Avenue       Brooklyn   11205.0
#
#             borough public_charger_ fee_for_city_drivers   latitude  \
# 0          Brooklyn             NaN                  NaN  40.668034
# 1          Brooklyn             NaN                  NaN  40.668034
# 2          Brooklyn             NaN                  NaN  40.668034
# 3     Staten Island             NaN                  NaN  40.640708
# 4         Manhattan             NaN                  NaN  40.712806
# ...             ...             ...                  ...        ...
# 1680          Bronx             NaN                  NaN  40.825928
# 1681    Westchester             NaN                  NaN        NaN
# 1682       Brooklyn             NaN                  NaN  40.600248
# 1683    Westchester             NaN                  NaN        NaN
# 1684       Brooklyn             NaN                  NaN  40.697144
#
#       longitude  community_district  council_district  census_tract  \
# 0    -73.869949               305.0              42.0        1220.0
# 1    -73.869949               305.0              42.0        1220.0
# 2    -73.869949               305.0              42.0        1220.0
# 3    -74.077697               501.0              49.0           3.0
# 4    -74.006096               101.0               1.0          31.0
# ...         ...                 ...               ...           ...
# 1680 -73.919514               204.0              16.0       18302.0
# 1681        NaN                 NaN               NaN           NaN
# 1682 -73.912051               318.0              46.0         666.0
# 1683        NaN                 NaN               NaN           NaN
# 1684 -73.953529               303.0              33.0        1237.0
#
#             bin           bbl     nta
# 0     3098733.0  3.044840e+09  BK0505
# 1     3098733.0  3.044840e+09  BK0505
# 2     3098733.0  3.044840e+09  BK0505
# 3     5000185.0  5.000160e+09  SI0101
# 4     1079147.0  1.001220e+09  MN0102
# ...         ...           ...     ...
# 1680  2097114.0  2.024440e+09  BX0401
# 1681        NaN           NaN     NaN
# 1682  3397327.0  3.085901e+09  BK1891
# 1683        NaN           NaN     NaN
# 1684  3426233.0  3.017180e+09  BK0301
#
# [1685 rows x 18 columns]

# %% [markdown]
# ## Preprocessing
#
# The raw CSV requires six cleaning steps before it can be used in the evaluation scenario.
#
# 1. **Drop stations without coordinates** - Stations missing `latitude` or `longitude` cannot participate in the geographic–topological bridge, which requires a valid WGS84 position to correlate each station with a ConEdison substation zone. The data dictionary notes that coordinates are geocoded by the Open Data team and may be absent for a small number of records.
# 2. **Fix column types** - `no_of_ports` is ingested as float because pandas promotes integer columns containing `NaN` to float; after step 1 the column is clean and can be safely cast. `postcode` must be stored as a zero-padded string to preserve codes with leading zeros (e.g. `07030`).
# 3. **Fill semantically empty fields** - The data dictionary explicitly states that blank values in `public_charger_` and `fee_for_city_drivers` mean the condition does not apply - equivalent to `"No"`. Retaining `NaN` would misrepresent these fields and produce incorrect results when filtering stations by public availability.
# 4. **Aggregate to station granularity** - The [data dictionary](https://data.cityofnewyork.us/api/views/fc53-9hrv/files/635c379a-691f-4986-8f5c-300b15cec89d?download=true&filename=NYC%20EV%20Fleet%20Station%20Network_Data%20Dictionary.xlsx) describes each record as a charging station. However, inspection of the raw export shows multiple records sharing the same agency and geocoded coordinates, often with different charger types. We therefore treat these records as charger-type entries and aggregate them into one station per (agency, latitude, longitude), summing no_of_ports and retaining the distinct charger types.
# 5. **Generate station ID** - Each station is assigned a unique identifier based on a normalized combination of agency, latitude, and longitude, hashed using SHA-256 to ensure uniqueness and consistency.
# 6. **Build GeoDataFrame** - Station coordinates are projected to EPSG:4326 (WGS84), the implicit CRS of GeoJSON per RFC 7946.

# %%
df = pd.read_csv(CSV_PATH)
print(f"Fetched {len(df)} rows from {CSV_PATH.name}")

# 1. Drop stations without coordinates
before = len(df)
df = df.dropna(subset=["latitude", "longitude"])
print(f"Dropped {before - len(df)} stations without coordinates - {len(df)} retained")

# 2. Fix column types
df["no_of_ports"] = df["no_of_ports"].astype(int)
df["postcode"] = df["postcode"].astype(int).astype(str).str.zfill(5)

# 3. Fill semantically empty fields (blank = "No" per data dictionary)
df["public_charger_"] = df["public_charger_"].fillna("No")
df["fee_for_city_drivers"] = df["fee_for_city_drivers"].fillna("No")

# 4. Aggregate to station granularity
before = len(df)
df = df.groupby(["agency", "latitude", "longitude"], sort=False).agg(
    agency=("agency", "first"),
    station_name=("street", lambda s: f"{df.loc[s.index, 'agency'].iloc[0]} - {s.iloc[0]}, {df.loc[s.index, 'borough'].iloc[0]}"),
    charger_types=("type_of_charger", lambda s: sorted(s.dropna().unique().tolist())),
    no_of_ports=("no_of_ports", "sum"),
    street=("street", "first"),
    city=("city", "first"),
    postcode=("postcode", "first"),
    borough=("borough", "first"),
    public_charger_=("public_charger_", "first"),
    fee_for_city_drivers=("fee_for_city_drivers", "first"),
    latitude=("latitude", "first"),
    longitude=("longitude", "first"),
    community_district=("community_district", "first"),
    council_district=("council_district", "first"),
    census_tract=("census_tract", "first"),
    bin=("bin", "first"),
    bbl=("bbl", "first"),
    nta=("nta", "first"),
).reset_index(drop=True)
print(f"Grouped {before - len(df)} stations by agency, latitude and longitude - {len(df)} retained")

# 5. Generate station ID
def _normalize(value):
    if pd.isna(value):
        return ""
    return " ".join(str(value).strip().upper().split())

station_key = (
    df["agency"].map(_normalize)
    + "|"
    + df["latitude"].map(lambda value: f"{value:.6f}")
    + "|"
    + df["longitude"].map(lambda value: f"{value:.6f}")
)

EV_STATION_ID_PREFIX = "urn:agentwin:city:ev-charging-station:"

df["station_id"] = (
    EV_STATION_ID_PREFIX
    + station_key.map(
        lambda value: hashlib.sha256(
            value.encode("utf-8")
        ).hexdigest()
    )
).astype(str)

# 6. Build GeoDataFrame
ev_stations = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df["longitude"], df["latitude"]),
    crs="EPSG:4326",
)

# Write to file
ev_stations.to_file(ROOT / "data/processed/ev_stations.geojson", driver="GeoJSON")
ev_stations.to_csv(ROOT / "data/processed/ev_stations.csv")

ev_stations
# Out:
# Fetched 1685 rows from dcas_ev_stations.csv
# Dropped 318 stations without coordinates - 1367 retained
# Grouped 849 stations by agency, latitude and longitude - 518 retained
#        agency                                 station_name  \
# 0         ACS             ACS - 2554 Linden Blvd, Brooklyn
# 1         ACS         ACS - 350 St Marks Pl, Staten Island
# 2    CITYHALL     CITYHALL - New York City Hall, Manhattan
# 3        DCAS                DCAS - 1 Centre St, Manhattan
# 4        DCAS                   DCAS - 2 Navy St, Brooklyn
# ..        ...                                          ...
# 513      DCAS            DCAS - 851 Grand Concourse, Bronx
# 514       DOE               DOE - 143 Baxter St, Manhattan
# 515      DSNY             DSNY - 455 Park Avenue, Brooklyn
# 516       DPR  DPR - 151 97th Street Transverse, Manhattan
# 517      DCAS                 DCAS - 265 E 161st St, Bronx
#
#                                     charger_types  no_of_ports  \
# 0         [Level 2 Charger, Level 3 Fast Charger]            3
# 1                               [Level 2 Charger]            1
# 2                               [Level 2 Charger]            4
# 3    [EV Solar Arc Charger, Level 3 Fast Charger]            3
# 4         [Level 2 Charger, Level 3 Fast Charger]            5
# ..                                            ...          ...
# 513                             [Level 2 Charger]            1
# 514                             [Level 2 Charger]            2
# 515                             [Level 2 Charger]            2
# 516                             [Level 2 Charger]            4
# 517                             [Level 2 Charger]            2
#
#                          street           city postcode        borough  \
# 0              2554 Linden Blvd  East New York    11208       Brooklyn
# 1               350 St Marks Pl  Staten Island    10301  Staten Island
# 2            New York City Hall       New York    10007      Manhattan
# 3                   1 Centre St       New York    10007      Manhattan
# 4                     2 Navy St       Brooklyn    11201       Brooklyn
# ..                          ...            ...      ...            ...
# 513         851 Grand Concourse          Bronx    10451          Bronx
# 514               143 Baxter St      Manhattan    10013      Manhattan
# 515             455 Park Avenue       Brooklyn    11205       Brooklyn
# 516  151 97th Street Transverse       New York    10029      Manhattan
# 517              265 E 161st St          Bronx    10451          Bronx
#
#     public_charger_ fee_for_city_drivers   latitude  longitude  \
# 0                No                   No  40.668034 -73.869949
# 1                No                   No  40.640708 -74.077697
# 2                No                   No  40.712806 -74.006096
# 3                No                   No  40.713001 -74.004181
# 4                No                   No  40.700610 -73.980420
# ..              ...                  ...        ...        ...
# 513              No                   No  40.826048 -73.923102
# 514              No                   No  40.718903 -73.998438
# 515              No                   No  40.696528 -73.958885
# 516              No                   No  40.790363 -73.960055
# 517              No                   No  40.825928 -73.919514
#
#      community_district  council_district  census_tract        bin  \
# 0                 305.0              42.0        1220.0  3098733.0
# 1                 501.0              49.0           3.0  5000185.0
# 2                 101.0               1.0          31.0  1079147.0
# 3                 101.0               1.0        2901.0  1001394.0
# 4                 302.0              35.0          23.0        NaN
# ..                  ...               ...           ...        ...
# 513               204.0              16.0        6301.0  2002869.0
# 514               102.0               1.0          41.0  1003086.0
# 515               303.0              33.0        1237.0  3329789.0
# 516               164.0               6.0         143.0  1083840.0
# 517               204.0              16.0       18302.0  2097114.0
#
#               bbl     nta                                         station_id  \
# 0    3.044840e+09  BK0505  urn:agentwin:city:ev-charging-station:4e553805...
# 1    5.000160e+09  SI0101  urn:agentwin:city:ev-charging-station:78800793...
# 2    1.001220e+09  MN0102  urn:agentwin:city:ev-charging-station:5534de34...
# 3    1.001210e+09  MN0102  urn:agentwin:city:ev-charging-station:20506606...
# 4             NaN  BK0202  urn:agentwin:city:ev-charging-station:f97f5bcd...
# ..            ...     ...                                                ...
# 513  2.024680e+09  BX0401  urn:agentwin:city:ev-charging-station:3845beba...
# 514  1.002360e+09  MN0201  urn:agentwin:city:ev-charging-station:30de416d...
# 515  3.018840e+09  BK0301  urn:agentwin:city:ev-charging-station:4fafdcff...
# 516  1.011110e+09  MN6491  urn:agentwin:city:ev-charging-station:3419ca6a...
# 517  2.024440e+09  BX0401  urn:agentwin:city:ev-charging-station:d6301686...
#
#                        geometry
# 0    POINT (-73.86995 40.66803)
# 1     POINT (-74.0777 40.64071)
# 2     POINT (-74.0061 40.71281)
# 3      POINT (-74.00418 40.713)
# 4    POINT (-73.98042 40.70061)
# ..                          ...
# 513   POINT (-73.9231 40.82605)
# 514   POINT (-73.99844 40.7189)
# 515  POINT (-73.95888 40.69653)
# 516  POINT (-73.96006 40.79036)
# 517  POINT (-73.91951 40.82593)
#
# [518 rows x 20 columns]

# %% [markdown]
# ## Visualization

# %%
map = folium.Map(location=[ev_stations.geometry.y.mean(), ev_stations.geometry.x.mean()],
               zoom_start=10)

folium.GeoJson(
    ev_stations,
    name="EV Stations",
    tooltip=folium.GeoJsonTooltip(fields=["station_name"]),
    popup=folium.GeoJsonPopup(fields=["station_name", "borough", "no_of_ports", "charger_types"]),
    marker=folium.Marker(
        icon=folium.Icon(
            prefix="fa", icon="charging-station", color="darkblue", icon_color="white"
        )
    ),
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6175d6d7fcb9cff7032d51e362dc0a28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6175d6d7fcb9cff7032d51e362dc0a28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6175d6d7fcb9cff7032d51e362dc0a28 = L.map(
#                 &quot;map_6175d6d7fcb9cff7032d51e362dc0a28&quot;,
#                 {
#                     center: [40.72212753281853, -73.93160938223937],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2b50543c0d5e2db0ad18185f0d00500 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b2b50543c0d5e2db0ad18185f0d00500.addTo(map_6175d6d7fcb9cff7032d51e362dc0a28);
#
#
#         function geo_json_c5b966cd3460cb44188545527f25e283_pointToLayer(feature, latlng) {
#             var opts = {
# };
#
#             const iconOptions = {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;charging-station&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             const iconRootAlias = L.AwesomeMarkers
#             opts.icon = new iconRootAlias.Icon(iconOptions)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_c5b966cd3460cb44188545527f25e283_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_c5b966cd3460cb44188545527f25e283 = L.geoJson(null, {
#                 onEachFeature: geo_json_c5b966cd3460cb44188545527f25e283_onEachFeature,
#
#                 pointToLayer: geo_json_c5b966cd3460cb44188545527f25e283_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_c5b966cd3460cb44188545527f25e283_add (data) {
#             geo_json_c5b966cd3460cb44188545527f25e283
#                 .addData(data);
#         }
#             geo_json_c5b966cd3460cb44188545527f25e283_add({&quot;bbox&quot;: [-74.25144, 40.502357, -73.727535, 40.908297], &quot;features&quot;: [{&quot;bbox&quot;: [-73.869949, 40.668034, -73.869949, 40.668034], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.869949, 40.668034], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;agency&quot;: &quot;ACS&quot;, &quot;bbl&quot;: 3044840013.0, &quot;bin&quot;: 3098733.0, &quot;borough&quot;: &quot;Brooklyn&quot;, &quot;census_tract&quot;: 1220.0, &quot;charger_types&quot;: [&quot;Level 2 Charger&quot;, &quot;Level 3 Fast Charger&quot;], &quot;city&quot;: &quot;East New York&quot;, &quot;community_district&quot;: 305.0, &quot;council_district&quot;: 42.0, &quot;fee_for_city_drivers&quot;: &quot;No&quot;, &quot;latitude&quot;: 40.668034, &quot;longitude&quot;: -73.869949, &quot;no_of_ports&quot;: 3, &quot;nta&quot;: &quot;BK0505&quot;, &quot;postcode&quot;: &quot;11208&quot;, &quot;public_charger_&quot;: &quot;No&quot;, &quot;station_id&quot;: &quot;urn:agentwin:city:ev-charging-station:4e55380591804d5a51f8a8af547ae27ec0b105f0e571b8f3ef14436d2b8720ff&quot;, &quot;station_name&quot;: &quot;ACS - 2554 Linden Blvd, Brooklyn&quot;, &quot;street&quot;: &quot;2554 Linden Blvd&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-74.077697, 40.640708, -74.077697, 40.640708], &quot;geometry&quot;: {&quot;coordinates&quot;: [-74.077697, 40.640708], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;agency&q

# %% [markdown]
# ## Ontology Field Derivation
#
# The processed station dataset is transformed into fields defined by the `EVChargingStation` ontology and its inherited `NGSILDBaseModel`.
#
# 1. **Create the digital-twin dataset** - A new GeoDataFrame is created with the station geometries and WGS84 coordinate reference system preserved.
#
# 2. **Derive charging capacity** - `no_of_ports` is mapped to `socketNumber`, `capacity`, and `availableCapacity`.
#
# 3. **Derive allowed vehicle type** - Agency codes are mapped to the ontology's `allowedVehicleType` enumeration where their operational role provides a clear vehicle class, such as `DSNY` to `truck` and `DOE` to `bus`. All other agencies default to `car`, reflecting the predominant fleet vehicle type while preserving the ontology's required vocabulary.
#
# 4. **Set operational fields** - Every record receives `status = "working"`. `operator` is populated from the station's `agency` code.
#
# 5. **Populate shared base-model properties** - `dataProvider` is set to `NYC DCAS Open Data`, `name` is populated from the derived station name, and `description` identifies each record as an NYC fleet EV charging station. Record-level creation and modification timestamps are left unset because they are not supplied by the source.
#
# 6. **Construct the address component** - The inherited `address` component is populated from the source `street`, `city`, and `postcode` columns. `addressCountry` and `addressRegion` are assigned the constant values `US` and `NY`. No value is supplied for `postOfficeBoxNumber`, because the data contains no corresponding field.
#
# 7. **Construct the geolocation component** - Each station geometry is converted into a `location` component with `type = "Point"`. Coordinates are serialized in GeoJSON order, `[longitude, latitude]`, using the point's `x` then `y` values. The coordinate pair is JSON-encoded because the ontology declares `geoLocation.coordinates` as a string.

# %%
AGENCY_VEHICLE_TYPE = {
    "NYPD": "car",
    "FDNY": "car",
    "DSNY": "truck",
    "DOE": "bus",
    "NYCEM": "caravan",
}

address = pd.DataFrame(
    {
        "addressCountry": "US",
        "addressLocality": ev_stations["city"],
        "addressRegion": "NY",
        "postalCode": ev_stations["postcode"],
        "streetAddress": ev_stations["street"],
    },
    index=ev_stations.index,
).to_dict(orient="records")

ev_stations_dtwin = pd.DataFrame(
    {
        "id": ev_stations["station_id"],
        "socketNumber": ev_stations["no_of_ports"],
        "capacity": ev_stations["no_of_ports"],
        "availableCapacity": ev_stations["no_of_ports"],
        "allowedVehicleType": ev_stations["agency"].map(AGENCY_VEHICLE_TYPE).fillna("car"),
        "status": "working",
        "operator": ev_stations["agency"],
        "dataProvider": "NYC DCAS Open Data",
        "name": ev_stations["station_name"],
        "description": "EV charging station operated for the NYC fleet.",
        "address": address,
        "location": ev_stations.geometry.map(
            lambda point: {
                "type": "Point",
                "coordinates": json.dumps([point.x, point.y, 0]),
            }
        ),
    }
)

ev_stations_dtwin
# Out:
#                                                     id  socketNumber  \
# 0    urn:agentwin:city:ev-charging-station:4e553805...             3
# 1    urn:agentwin:city:ev-charging-station:78800793...             1
# 2    urn:agentwin:city:ev-charging-station:5534de34...             4
# 3    urn:agentwin:city:ev-charging-station:20506606...             3
# 4    urn:agentwin:city:ev-charging-station:f97f5bcd...             5
# ..                                                 ...           ...
# 513  urn:agentwin:city:ev-charging-station:3845beba...             1
# 514  urn:agentwin:city:ev-charging-station:30de416d...             2
# 515  urn:agentwin:city:ev-charging-station:4fafdcff...             2
# 516  urn:agentwin:city:ev-charging-station:3419ca6a...             4
# 517  urn:agentwin:city:ev-charging-station:d6301686...             2
#
#      capacity  availableCapacity allowedVehicleType   status  operator  \
# 0           3                  3                car  working       ACS
# 1           1                  1                car  working       ACS
# 2           4                  4                car  working  CITYHALL
# 3           3                  3                car  working      DCAS
# 4           5                  5                car  working      DCAS
# ..        ...                ...                ...      ...       ...
# 513         1                  1                car  working      DCAS
# 514         2                  2                bus  working       DOE
# 515         2                  2              truck  working      DSNY
# 516         4                  4                car  working       DPR
# 517         2                  2                car  working      DCAS
#
#            dataProvider                                         name  \
# 0    NYC DCAS Open Data             ACS - 2554 Linden Blvd, Brooklyn
# 1    NYC DCAS Open Data         ACS - 350 St Marks Pl, Staten Island
# 2    NYC DCAS Open Data     CITYHALL - New York City Hall, Manhattan
# 3    NYC DCAS Open Data                DCAS - 1 Centre St, Manhattan
# 4    NYC DCAS Open Data                   DCAS - 2 Navy St, Brooklyn
# ..                  ...                                          ...
# 513  NYC DCAS Open Data            DCAS - 851 Grand Concourse, Bronx
# 514  NYC DCAS Open Data               DOE - 143 Baxter St, Manhattan
# 515  NYC DCAS Open Data             DSNY - 455 Park Avenue, Brooklyn
# 516  NYC DCAS Open Data  DPR - 151 97th Street Transverse, Manhattan
# 517  NYC DCAS Open Data                 DCAS - 265 E 161st St, Bronx
#
#                                          description  \
# 0    EV charging station operated for the NYC fleet.
# 1    EV charging station operated for the NYC fleet.
# 2    EV charging station operated for the NYC fleet.
# 3    EV charging station operated for the NYC fleet.
# 4    EV charging station operated for the NYC fleet.
# ..                                               ...
# 513  EV charging station operated for the NYC fleet.
# 514  EV charging station operated for the NYC fleet.
# 515  EV charging station operated for the NYC fleet.
# 516  EV charging station operated for the NYC fleet.
# 517  EV charging station operated for the NYC fleet.
#
#                                                address  \
# 0    {'addressCountry': 'US', 'addressLocality': 'E...
# 1    {'addressCountry': 'US', 'addressLocality': 'S...
# 2    {'addressCountry': 'US', 'addressLocality': 'N...
# 3    {'addressCountry': 'US', 'addressLocality': 'N...
# 4    {'addressCountry': 'US', 'addressLocality': 'B...
# ..                                                 ...
# 513  {'addressCountry': 'US', 'addressLocality': 'B...
# 514  {'addressCountry': 'US', 'addressLocality': 'M...
# 515  {'addressCountry': 'US', 'addressLocality': 'B...
# 516  {'addressCountry': 'US', 'addressLocality': 'N...
# 517  {'addressCountry': 'US', 'addressLocality': 'B...
#
#                                               location
# 0    {'type': 'Point', 'coordinates': '[-73.869949,...
# 1    {'type': 'Point', 'coordinates': '[-74.077697,...
# 2    {'type': 'Point', 'coordinates': '[-74.006096,...
# 3    {'type': 'Point', 'coordinates': '[-74.004181,...
# 4    {'type': 'Point', 'coordinates': '[-73.98042, ...
# ..                                                 ...
# 513  {'type': 'Point', 'coordinates': '[-73.923102,...
# 514  {'type': 'Point', 'coordinates': '[-73.998438,...
# 515  {'type': 'Point', 'coordinates': '[-73.958885,...
# 516  {'type': 'Point', 'coordinates': '[-73.960055,...
# 517  {'type': 'Point', 'coordinates': '[-73.919514,...
#
# [518 rows x 12 columns]
