# %% [markdown]
# # NYC Substations
#
# | | |
# |---|---|
# | **Source** | OpenStreetMap (OSM) |
# | **URL** | [openstreetmap.org](https://www.openstreetmap.org) |
# | **Granularity** | One row per mapped `power=substation` feature |
# | **Data collection** | Volunteered geographic information; no official publisher or data dictionary |
#
# NYC power substations are not published as an open dataset by ConEdison or any city agency; grid infrastructure location is treated as a national security concern and is not released with a formal schema. This dataset is instead derived from OpenStreetMap, a community-maintained map where contributors tag real-world features with free-form key/value pairs. There is no authoritative data dictionary for these tags: descriptions below follow the informal conventions documented on the [OSM Wiki](https://wiki.openstreetmap.org/wiki/Tag:power=substation), and coverage/consistency depends entirely on what volunteers have mapped.
#
# ## Column Reference
#
# OSM tags are optional and inconsistently populated. The columns below are the tags retained after processing; any tag not listed was dropped as out of scope for this baseline, not necessarily because it lacks value.
#
# | Column | Description | Notes |
# |---|---|---|
# | `id` | OSM feature identifier (node/way) | Stable within an OSM snapshot, not a ConEdison asset ID |
# | `name` | Human-assigned substation name | Frequently missing; not all substations are named by contributors |
# | `power` | OSM feature category | Constant `substation` by construction of the query tags |
# | `operator` | Free-text operator tag | Used to scope this dataset to `Consolidated Edison`; volunteered, not verified against utility records |
# | `substation` | Substation function/voltage class (e.g. `transmission`, `distribution`) | Informal OSM subtag, not a controlled vocabulary |
# | `voltage` | Voltage level(s), semicolon-separated when multiple | Free text; units and formatting are not enforced |
# | `frequency` | Grid frequency in Hz | Usually `60` for NYC when present |
# | `geometry` | Feature location | Original OSM geometry may be a `Point`, `Polygon`, or other type depending on how the feature was mapped |

# %% [markdown]
# ## Data Acquisition

# %%
import json
import requests
import folium
from datetime import date
from pathlib import Path
import pandas as pd
import geopandas as gpd
import osmnx as ox

# %%
ROOT = Path("..").resolve()
BOUNDARIES_GEOJSON_PATH = ROOT / "data/raw/borough_boundaries.geojson"
PARAMS = {
    "tags": {"power": "substation"},
}
GEOJSON_PATH = ROOT / "data/raw/osm_substations.geojson"
META_GEOJSON_PATH = ROOT / "data/raw/osm_substations.geojson.meta.json"

# Fetch NYC power substations from OpenStreetMap inside borough boundaries
boroughs = gpd.read_file(BOUNDARIES_GEOJSON_PATH)
nyc_polygon = boroughs.union_all()

ox.settings.max_query_area_size = 5e9
ox.settings.cache_folder = "/tmp/osm_cache"

fetch_gdf = (
    gpd.read_file(GEOJSON_PATH)
    if GEOJSON_PATH.exists()
    else ox.features_from_polygon(nyc_polygon, tags=PARAMS["tags"])
)

if GEOJSON_PATH.exists():
    print(f"Already fetched → {GEOJSON_PATH}, skipping.")
else:
    GEOJSON_PATH.parent.mkdir(parents=True, exist_ok=True)
    fetch_gdf.to_file(GEOJSON_PATH, driver="GeoJSON")
    META_GEOJSON_PATH.write_text(
        json.dumps(
            {
                "fetched_date": str(date.today()),
                "source_url": "https://www.openstreetmap.org",
                "source_params": PARAMS,
                "row_count": len(fetch_gdf),
            },
            indent=2,
        )
    )
    print(f"Saved {GEOJSON_PATH.name} ({META_GEOJSON_PATH.read_text()})")
    
gpd.read_file(GEOJSON_PATH)
# Out:
# Already fetched → /home/henrique/source/repos/agentwin-dataset/data/raw/osm_substations.geojson, skipping.
#     element          id addr:state  ele gnis:feature_id  \
# 0      node   368062840         NY    2         2062029
# 1       way   108298302        NaN  NaN             NaN
# 2       way   108318934        NaN  NaN             NaN
# 3       way   108322562        NaN  NaN             NaN
# 4       way   108331538        NaN  NaN             NaN
# ..      ...         ...        ...  ...             ...
# 199     way  1485150724        NaN  NaN             NaN
# 200     way  1485150725        NaN  NaN             NaN
# 201     way  1485150726        NaN  NaN             NaN
# 202     way  1508559019        NaN  NaN             NaN
# 203     way  1540230931        NaN  NaN             NaN
#
#                           name       power         source barrier check_date  \
# 0    Port Morris Power Station  substation  USGS Geonames     NaN        NaT
# 1            Rainey Substation  substation            NaN     NaN        NaT
# 2                          NaN  substation            NaN     NaN        NaT
# 3            Vernon Substation  substation            NaN     NaN        NaT
# 4      North Queens Substation  substation            NaN   fence        NaT
# ..                         ...         ...            ...     ...        ...
# 199                        NaN  substation            NaN     NaN        NaT
# 200                        NaN  substation            NaN     NaN        NaT
# 201                        NaN  substation            NaN     NaN        NaT
# 202                        NaN  substation            NaN     NaN        NaT
# 203               Building 390  substation            NaN     NaN        NaT
#
#      ... website voltage:primary voltage:secondary  \
# 0    ...     NaN             NaN               NaN
# 1    ...     NaN             NaN               NaN
# 2    ...     NaN             NaN               NaN
# 3    ...     NaN             NaN               NaN
# 4    ...     NaN             NaN               NaN
# ..   ...     ...             ...               ...
# 199  ...     NaN             NaN               NaN
# 200  ...     NaN             NaN               NaN
# 201  ...     NaN             NaN               NaN
# 202  ...     NaN             NaN               NaN
# 203  ...     NaN             NaN               NaN
#
#                       description abandoned  protection_title  \
# 0                             NaN       NaN               NaN
# 1                             NaN       NaN               NaN
# 2                             NaN       NaN               NaN
# 3                             NaN       NaN               NaN
# 4                             NaN       NaN               NaN
# ..                            ...       ...               ...
# 199                           NaN       NaN               NaN
# 200                           NaN       NaN               NaN
# 201                           NaN       NaN               NaN
# 202                           NaN       NaN               NaN
# 203  Historical usage: Substation  building  City of New York
#
#                          source:1  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 199                           NaN
# 200                           NaN
# 201                           NaN
# 202                           NaN
# 203  Digital Archive on NPGallery
#
#                                           source_ref:1 start_date  \
# 0                                                  NaN        NaN
# 1                                                  NaN        NaN
# 2                                                  NaN        NaN
# 3                                                  NaN        NaN
# 4                                                  NaN        NaN
# ..                                                 ...        ...
# 199                                                NaN        NaN
# 200                                                NaN        NaN
# 201                                                NaN        NaN
# 202                                                NaN        NaN
# 203  https://npgallery.nps.gov/NRHP/AssetDetail/314...       1942
#
#                                               geometry
# 0                           POINT (-73.90291 40.80455)
# 1    POLYGON ((-73.94341 40.76417, -73.94344 40.764...
# 2    POLYGON ((-73.91051 40.78725, -73.90981 40.786...
# 3    POLYGON ((-73.94735 40.75878, -73.94591 40.758...
# 4    POLYGON ((-73.90605 40.78116, -73.90581 40.781...
# ..                                                 ...
# 199  POLYGON ((-73.89792 40.78213, -73.89807 40.782...
# 200  POLYGON ((-73.91294 40.78657, -73.91255 40.786...
# 201  POLYGON ((-73.91279 40.78606, -73.91258 40.786...
# 202  POLYGON ((-74.01227 40.7138, -74.01241 40.7132...
# 203  POLYGON ((-73.97052 40.70717, -73.97038 40.706...
#
# [204 rows x 57 columns]

# %%
CSV_PATH = ROOT / "data/raw/osm_substations.csv"
META_CSV_PATH = ROOT / "data/raw/osm_substations.csv.meta.json"

if CSV_PATH.exists():
    print(f"Already fetched → {CSV_PATH}, skipping.")
else:
    CSV_PATH.parent.mkdir(parents=True, exist_ok=True)
    fetch_gdf.to_csv(CSV_PATH, index=False)
    META_CSV_PATH.write_text(
        json.dumps(
            {
                "fetched_date": str(date.today()),
                "source_url": "https://www.openstreetmap.org",
                "source_params": PARAMS,
                "row_count": len(fetch_gdf),
            },
            indent=2,
        )
    )
    print(f"Saved {CSV_PATH.name} ({META_CSV_PATH.read_text()})")
    
pd.read_csv(CSV_PATH)
# Out:
# Already fetched → /home/henrique/source/repos/agentwin-dataset/data/raw/osm_substations.csv, skipping.
#                                               geometry addr:state  ele  \
# 0                       POINT (-73.9029142 40.8045454)         NY  2.0
# 1    POLYGON ((-73.9434133 40.7641675, -73.9434382 ...        NaN  NaN
# 2    POLYGON ((-73.9105054 40.7872511, -73.909806 4...        NaN  NaN
# 3    POLYGON ((-73.9473458 40.7587815, -73.945906 4...        NaN  NaN
# 4    POLYGON ((-73.9060539 40.7811609, -73.9058098 ...        NaN  NaN
# ..                                                 ...        ...  ...
# 199  POLYGON ((-73.8979161 40.7821327, -73.8980663 ...        NaN  NaN
# 200  POLYGON ((-73.9129445 40.7865672, -73.9125489 ...        NaN  NaN
# 201  POLYGON ((-73.9127876 40.7860554, -73.9125811 ...        NaN  NaN
# 202  POLYGON ((-74.0122726 40.7137959, -74.0124137 ...        NaN  NaN
# 203  POLYGON ((-73.970516 40.7071692, -73.9703765 4...        NaN  NaN
#
#      gnis:feature_id                       name       power         source  \
# 0          2062029.0  Port Morris Power Station  substation  USGS Geonames
# 1                NaN          Rainey Substation  substation            NaN
# 2                NaN                        NaN  substation            NaN
# 3                NaN          Vernon Substation  substation            NaN
# 4                NaN    North Queens Substation  substation            NaN
# ..               ...                        ...         ...            ...
# 199              NaN                        NaN  substation            NaN
# 200              NaN                        NaN  substation            NaN
# 201              NaN                        NaN  substation            NaN
# 202              NaN                        NaN  substation            NaN
# 203              NaN               Building 390  substation            NaN
#
#     barrier check_date fixme  ... building:part website voltage:primary  \
# 0       NaN        NaN   NaN  ...           NaN     NaN             NaN
# 1       NaN        NaN   NaN  ...           NaN     NaN             NaN
# 2       NaN        NaN   NaN  ...           NaN     NaN             NaN
# 3       NaN        NaN   NaN  ...           NaN     NaN             NaN
# 4     fence        NaN   NaN  ...           NaN     NaN             NaN
# ..      ...        ...   ...  ...           ...     ...             ...
# 199     NaN        NaN   NaN  ...           NaN     NaN             NaN
# 200     NaN        NaN   NaN  ...           NaN     NaN             NaN
# 201     NaN        NaN   NaN  ...           NaN     NaN             NaN
# 202     NaN        NaN   NaN  ...           NaN     NaN             NaN
# 203     NaN        NaN   NaN  ...           NaN     NaN             NaN
#
#     voltage:secondary                   description abandoned  \
# 0                 NaN                           NaN       NaN
# 1                 NaN                           NaN       NaN
# 2                 NaN                           NaN       NaN
# 3                 NaN                           NaN       NaN
# 4                 NaN                           NaN       NaN
# ..                ...                           ...       ...
# 199               NaN                           NaN       NaN
# 200               NaN                           NaN       NaN
# 201               NaN                           NaN       NaN
# 202               NaN                           NaN       NaN
# 203               NaN  Historical usage: Substation  building
#
#      protection_title                      source:1  \
# 0                 NaN                           NaN
# 1                 NaN                           NaN
# 2                 NaN                           NaN
# 3                 NaN                           NaN
# 4                 NaN                           NaN
# ..                ...                           ...
# 199               NaN                           NaN
# 200               NaN                           NaN
# 201               NaN                           NaN
# 202               NaN                           NaN
# 203  City of New York  Digital Archive on NPGallery
#
#                                           source_ref:1 start_date
# 0                                                  NaN        NaN
# 1                                                  NaN        NaN
# 2                                                  NaN        NaN
# 3                                                  NaN        NaN
# 4                                                  NaN        NaN
# ..                                                 ...        ...
# 199                                                NaN        NaN
# 200                                                NaN        NaN
# 201                                                NaN        NaN
# 202                                                NaN        NaN
# 203  https://npgallery.nps.gov/NRHP/AssetDetail/314...     1942.0
#
# [204 rows x 55 columns]

# %% [markdown]
# ## Processing
#
# The raw OSM extract requires five cleaning steps before it can be used as the baseline substation dataset. Because OSM has no formal schema, these steps favor explicit, documented decisions over blanket missing-value heuristics.
#
# 1. **Keep relevant columns** - Most OSM tags on this extract (e.g. `source`, `element`, `location`, `operator:wikidata`) are sparse, contributor-dependent metadata not needed for the current scenario; they remain available in the raw snapshot for provenance.
# 2. **Scope to Consolidated Edison** - The dataset is restricted to features whose `operator` tag equals `Consolidated Edison`. This reflects OSM tagging, not a verified utility service-territory boundary; substations with a missing or differently formatted operator tag are excluded even if they may belong to ConEdison.
# 3. **Derive a representative point** - OSM substations may be mapped as points, polygons, or other geometry types depending on how contributors surveyed them. A single representative point is derived for consistent downstream use.
# 4. **Require a unique, non-null id** - The OSM `id` is the only stable identifier available and is used to drop untagged and duplicate features.
# 5. **Derive ontology entity IDs** - Unique identifiers for substations, locations, and position points are derived using consistent URN prefixes.

# %%
substations = gpd.read_file(GEOJSON_PATH)
print(f"Fetched {len(substations)} rows from {GEOJSON_PATH.name}")

# 1. Filter to only include relevant columns
substations = substations[
    [
        "id",
        "name",
        "power",
        "operator",
        "substation",
        "voltage",
        "frequency",
        "geometry",
    ]
]

# 2. Restrict the baseline to OSM features tagged as ConEdison-operated.
substations = substations[substations["operator"] == "Consolidated Edison"]

# 3. Derive representative locations.
substations = substations.set_geometry(substations.geometry.representative_point())

# 4. Require a non-null, unique OSM identifier.
substations = substations.dropna(subset=["id"]).drop_duplicates(subset=["id"])

# 5. Derive IDs for ontology entities relationship
SUBSTATION_ID_PREFIX = "urn:agentwin:energy:substation:osm:"
LOCATION_ID_PREFIX = "urn:agentwin:energy:location:osm:"
POSITION_POINT_ID_PREFIX = "urn:agentwin:energy:position-point:osm:"
COORDINATE_SYSTEM_ID = "urn:agentwin:energy:coordinate-system:osm:2263"

substations = substations.assign(
    substation_id=SUBSTATION_ID_PREFIX + substations["id"].astype(str),
    location_id=LOCATION_ID_PREFIX + substations["id"].astype(str),
    coordinate_system_id=COORDINATE_SYSTEM_ID,
    position_point_id=POSITION_POINT_ID_PREFIX + substations["id"].astype(str),
)

# Write to file
substations.to_file(ROOT / "data/processed/substations.geojson", driver="GeoJSON")
substations.to_csv(ROOT / "data/processed/substations.csv")


print(f"Processed {len(substations)} rows from {GEOJSON_PATH.name} and saved to processed files.")

substations
# Out:
# Fetched 204 rows from osm_substations.geojson
# Processed 104 rows from osm_substations.geojson and saved to processed files.
#              id                         name       power             operator  \
# 1     108298302            Rainey Substation  substation  Consolidated Edison
# 3     108322562            Vernon Substation  substation  Consolidated Edison
# 4     108331538      North Queens Substation  substation  Consolidated Edison
# 6     187984305           Jamaica Substation  substation  Consolidated Edison
# 8     188367030  West 49th Street Substation  substation  Consolidated Edison
# ..          ...                          ...         ...                  ...
# 191  1338654396          11th Street Conduit  substation  Consolidated Edison
# 192  1338654415          11th Street Conduit  substation  Consolidated Edison
# 195  1434668163           Woodrow Substation  substation  Consolidated Edison
# 196  1472076552       Willowbrook Substation  substation  Consolidated Edison
# 202  1508559019                          NaN  substation  Consolidated Edison
#
#              substation                  voltage frequency  \
# 1          transmission            345000;138000        60
# 3          distribution                   138000        60
# 4          distribution             138000;27000        60
# 6          transmission             138000;27000        60
# 8          transmission                   345000        60
# ..                  ...                      ...       ...
# 191                 NaN                      NaN       NaN
# 192                 yes                      NaN       NaN
# 195        distribution             138000;13200        60
# 196        distribution  138000;33000;13200;4000        50
# 202  minor_distribution             138000;13200       NaN
#
#                        geometry  \
# 1    POINT (-73.94301 40.76329)
# 3    POINT (-73.94692 40.75802)
# 4    POINT (-73.90674 40.78177)
# 6    POINT (-73.81391 40.69919)
# 8    POINT (-73.99597 40.76604)
# ..                          ...
# 191  POINT (-73.95241 40.73839)
# 192  POINT (-73.95075 40.74406)
# 195   POINT (-74.21525 40.5548)
# 196  POINT (-74.14564 40.61078)
# 202  POINT (-74.01226 40.71348)
#
#                                      substation_id  \
# 1     urn:agentwin:energy:substation:osm:108298302
# 3     urn:agentwin:energy:substation:osm:108322562
# 4     urn:agentwin:energy:substation:osm:108331538
# 6     urn:agentwin:energy:substation:osm:187984305
# 8     urn:agentwin:energy:substation:osm:188367030
# ..                                             ...
# 191  urn:agentwin:energy:substation:osm:1338654396
# 192  urn:agentwin:energy:substation:osm:1338654415
# 195  urn:agentwin:energy:substation:osm:1434668163
# 196  urn:agentwin:energy:substation:osm:1472076552
# 202  urn:agentwin:energy:substation:osm:1508559019
#
#                                      location_id  \
# 1     urn:agentwin:energy:location:osm:108298302
# 3     urn:agentwin:energy:location:osm:108322562
# 4     urn:agentwin:energy:location:osm:108331538
# 6     urn:agentwin:energy:location:osm:187984305
# 8     urn:agentwin:energy:location:osm:188367030
# ..                                           ...
# 191  urn:agentwin:energy:location:osm:1338654396
# 192  urn:agentwin:energy:location:osm:1338654415
# 195  urn:agentwin:energy:location:osm:1434668163
# 196  urn:agentwin:energy:location:osm:1472076552
# 202  urn:agentwin:energy:location:osm:1508559019
#
#                                coordinate_system_id  \
# 1    urn:agentwin:energy:coordinate-system:osm:2263
# 3    urn:agentwin:energy:coordinate-system:osm:2263
# 4    urn:agentwin:energy:coordinate-system:osm:2263
# 6    urn:agentwin:energy:coordinate-system:osm:2263
# 8    urn:agentwin:energy:coordinate-system:osm:2263
# ..                                              ...
# 191  urn:agentwin:energy:coordinate-system:osm:2263
# 192  urn:agentwin:energy:coordinate-system:osm:2263
# 195  urn:agentwin:energy:coordinate-system:osm:2263
# 196  urn:agentwin:energy:coordinate-system:osm:2263
# 202  urn:agentwin:energy:coordinate-system:osm:2263
#
#                                      position_point_id
# 1     urn:agentwin:energy:position-point:osm:108298302
# 3     urn:agentwin:energy:position-point:osm:108322562
# 4     urn:agentwin:energy:position-point:osm:108331538
# 6     urn:agentwin:energy:position-point:osm:187984305
# 8     urn:agentwin:energy:position-point:osm:188367030
# ..                                                 ...
# 191  urn:agentwin:energy:position-point:osm:1338654396
# 192  urn:agentwin:energy:position-point:osm:1338654415
# 195  urn:agentwin:energy:position-point:osm:1434668163
# 196  urn:agentwin:energy:position-point:osm:1472076552
# 202  urn:agentwin:energy:position-point:osm:1508559019
#
# [104 rows x 12 columns]

# %% [markdown]
# ## Visualization

# %%
map = folium.Map(
    location=[substations.geometry.y.mean(), substations.geometry.x.mean()],
    zoom_start=10,
)

folium.GeoJson(
    substations,
    name="Substations",
    tooltip=folium.GeoJsonTooltip(fields=["name"]),
    popup=folium.GeoJsonPopup(fields=["name", "substation", "voltage", "frequency"]),
    marker=folium.Marker(
        icon=folium.Icon(
            prefix="fa", icon="industry", color="darkred", icon_color="white"
        )
    ),
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50fe2f3178e0383b2725f176ca291254 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50fe2f3178e0383b2725f176ca291254&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50fe2f3178e0383b2725f176ca291254 = L.map(
#                 &quot;map_50fe2f3178e0383b2725f176ca291254&quot;,
#                 {
#                     center: [40.70595921153846, -73.9178419093415],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9d9938463d3d54ee04698817e3b2142 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f9d9938463d3d54ee04698817e3b2142.addTo(map_50fe2f3178e0383b2725f176ca291254);
#
#
#         function geo_json_aa1b8f5bced72a07624a2308e2156abc_pointToLayer(feature, latlng) {
#             var opts = {
# };
#
#             const iconOptions = {
#   &quot;markerColor&quot;: &quot;darkred&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;industry&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             const iconRootAlias = L.AwesomeMarkers
#             opts.icon = new iconRootAlias.Icon(iconOptions)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_aa1b8f5bced72a07624a2308e2156abc_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_aa1b8f5bced72a07624a2308e2156abc = L.geoJson(null, {
#                 onEachFeature: geo_json_aa1b8f5bced72a07624a2308e2156abc_onEachFeature,
#
#                 pointToLayer: geo_json_aa1b8f5bced72a07624a2308e2156abc_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_aa1b8f5bced72a07624a2308e2156abc_add (data) {
#             geo_json_aa1b8f5bced72a07624a2308e2156abc
#                 .addData(data);
#         }
#             geo_json_aa1b8f5bced72a07624a2308e2156abc_add({&quot;bbox&quot;: [-74.21524609093305, 40.55480105, -73.7069517883217, 40.8605917], &quot;features&quot;: [{&quot;bbox&quot;: [-73.94301433655147, 40.76328875, -73.94301433655147, 40.76328875], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.94301433655147, 40.76328875], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;coordinate_system_id&quot;: &quot;urn:agentwin:energy:coordinate-system:osm:2263&quot;, &quot;frequency&quot;: &quot;60&quot;, &quot;id&quot;: 108298302, &quot;location_id&quot;: &quot;urn:agentwin:energy:location:osm:108298302&quot;, &quot;name&quot;: &quot;Rainey Substation&quot;, &quot;operator&quot;: &quot;Consolidated Edison&quot;, &quot;position_point_id&quot;: &quot;urn:agentwin:energy:position-point:osm:108298302&quot;, &quot;power&quot;: &quot;substation&quot;, &quot;substation&quot;: &quot;transmission&quot;, &quot;substation_id&quot;: &quot;urn:agentwin:energy:substation:osm:108298302&quot;, &quot;voltage&quot;: &quot;345000;138000&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-73.94692354614071, 40.7580157, -73.94692354614071, 40.7580157], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.94692354614071, 40.7580157], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;coordinate_system_id&quot;: &quot;urn:agentwin:energy:coordinate-system:osm:2263&quot;, &quot;frequency&quot;: &quot;60&quot;, &quot;id&quot;: 108322562, &quot;location_id&quot;: &quot;urn:agent

# %% [markdown]
# ## Ontology Field Derivation

# %%
substations_dtwin = pd.DataFrame(
    {
        "id": substations["substation_id"],
        "mRID": "osm:substation:" + substations["id"].astype(str),
        "name": substations["name"],
        "substationName": substations["name"],
        "location": substations["location_id"]
    }
)

substations_dtwin
# Out:
#                                                 id                       mRID  \
# 1     urn:agentwin:energy:substation:osm:108298302   osm:substation:108298302
# 3     urn:agentwin:energy:substation:osm:108322562   osm:substation:108322562
# 4     urn:agentwin:energy:substation:osm:108331538   osm:substation:108331538
# 6     urn:agentwin:energy:substation:osm:187984305   osm:substation:187984305
# 8     urn:agentwin:energy:substation:osm:188367030   osm:substation:188367030
# ..                                             ...                        ...
# 191  urn:agentwin:energy:substation:osm:1338654396  osm:substation:1338654396
# 192  urn:agentwin:energy:substation:osm:1338654415  osm:substation:1338654415
# 195  urn:agentwin:energy:substation:osm:1434668163  osm:substation:1434668163
# 196  urn:agentwin:energy:substation:osm:1472076552  osm:substation:1472076552
# 202  urn:agentwin:energy:substation:osm:1508559019  osm:substation:1508559019
#
#                             name               substationName  \
# 1              Rainey Substation            Rainey Substation
# 3              Vernon Substation            Vernon Substation
# 4        North Queens Substation      North Queens Substation
# 6             Jamaica Substation           Jamaica Substation
# 8    West 49th Street Substation  West 49th Street Substation
# ..                           ...                          ...
# 191          11th Street Conduit          11th Street Conduit
# 192          11th Street Conduit          11th Street Conduit
# 195           Woodrow Substation           Woodrow Substation
# 196       Willowbrook Substation       Willowbrook Substation
# 202                          NaN                          NaN
#
#                                         location
# 1     urn:agentwin:energy:location:osm:108298302
# 3     urn:agentwin:energy:location:osm:108322562
# 4     urn:agentwin:energy:location:osm:108331538
# 6     urn:agentwin:energy:location:osm:187984305
# 8     urn:agentwin:energy:location:osm:188367030
# ..                                           ...
# 191  urn:agentwin:energy:location:osm:1338654396
# 192  urn:agentwin:energy:location:osm:1338654415
# 195  urn:agentwin:energy:location:osm:1434668163
# 196  urn:agentwin:energy:location:osm:1472076552
# 202  urn:agentwin:energy:location:osm:1508559019
#
# [104 rows x 5 columns]

# %%
location_dtwin = pd.DataFrame(
    {
        "id": substations["location_id"],
        "locationName": substations["name"],
        "coordinateSystem": substations["coordinate_system_id"],
        "positionPoints": substations["position_point_id"]
    }
)

location_dtwin
# Out:
#                                               id                 locationName  \
# 1     urn:agentwin:energy:location:osm:108298302            Rainey Substation
# 3     urn:agentwin:energy:location:osm:108322562            Vernon Substation
# 4     urn:agentwin:energy:location:osm:108331538      North Queens Substation
# 6     urn:agentwin:energy:location:osm:187984305           Jamaica Substation
# 8     urn:agentwin:energy:location:osm:188367030  West 49th Street Substation
# ..                                           ...                          ...
# 191  urn:agentwin:energy:location:osm:1338654396          11th Street Conduit
# 192  urn:agentwin:energy:location:osm:1338654415          11th Street Conduit
# 195  urn:agentwin:energy:location:osm:1434668163           Woodrow Substation
# 196  urn:agentwin:energy:location:osm:1472076552       Willowbrook Substation
# 202  urn:agentwin:energy:location:osm:1508559019                          NaN
#
#                                    coordinateSystem  \
# 1    urn:agentwin:energy:coordinate-system:osm:2263
# 3    urn:agentwin:energy:coordinate-system:osm:2263
# 4    urn:agentwin:energy:coordinate-system:osm:2263
# 6    urn:agentwin:energy:coordinate-system:osm:2263
# 8    urn:agentwin:energy:coordinate-system:osm:2263
# ..                                              ...
# 191  urn:agentwin:energy:coordinate-system:osm:2263
# 192  urn:agentwin:energy:coordinate-system:osm:2263
# 195  urn:agentwin:energy:coordinate-system:osm:2263
# 196  urn:agentwin:energy:coordinate-system:osm:2263
# 202  urn:agentwin:energy:coordinate-system:osm:2263
#
#                                         positionPoints
# 1     urn:agentwin:energy:position-point:osm:108298302
# 3     urn:agentwin:energy:position-point:osm:108322562
# 4     urn:agentwin:energy:position-point:osm:108331538
# 6     urn:agentwin:energy:position-point:osm:187984305
# 8     urn:agentwin:energy:position-point:osm:188367030
# ..                                                 ...
# 191  urn:agentwin:energy:position-point:osm:1338654396
# 192  urn:agentwin:energy:position-point:osm:1338654415
# 195  urn:agentwin:energy:position-point:osm:1434668163
# 196  urn:agentwin:energy:position-point:osm:1472076552
# 202  urn:agentwin:energy:position-point:osm:1508559019
#
# [104 rows x 4 columns]

# %%
coordinate_systems_dtwin = pd.DataFrame(
  {
    "id": [COORDINATE_SYSTEM_ID],
    "name": ["NAD83 / New York Long Island"],
    "crsUrn": ["urn:ogc:def:crs:EPSG::2263"]
  }
)

coordinate_systems_dtwin
# Out:
#                                                id  \
# 0  urn:agentwin:energy:coordinate-system:osm:2263
#
#                            name                      crsUrn
# 0  NAD83 / New York Long Island  urn:ogc:def:crs:EPSG::2263

# %%
position_points_projected = substations.to_crs(epsg=2263)

position_points_dtwin = pd.DataFrame(
    {
        "id": substations["position_point_id"],
        "xPosition": position_points_projected.geometry.x,
        "yPosition": position_points_projected.geometry.y,
        "zPosition": 0,
        "sequenceNumber": 0
    }
)

position_points_dtwin
# Out:
#                                                     id     xPosition  \
# 1     urn:agentwin:energy:position-point:osm:108298302  1.000036e+06
# 3     urn:agentwin:energy:position-point:osm:108322562  9.989543e+05
# 4     urn:agentwin:energy:position-point:osm:108331538  1.010078e+06
# 6     urn:agentwin:energy:position-point:osm:187984305  1.035850e+06
# 8     urn:agentwin:energy:position-point:osm:188367030  9.853668e+05
# ..                                                 ...           ...
# 191  urn:agentwin:energy:position-point:osm:1338654396  9.974393e+05
# 192  urn:agentwin:energy:position-point:osm:1338654415  9.978958e+05
# 195  urn:agentwin:energy:position-point:osm:1434668163  9.244365e+05
# 196  urn:agentwin:energy:position-point:osm:1472076552  9.438114e+05
# 202  urn:agentwin:energy:position-point:osm:1508559019  9.808504e+05
#
#          yPosition  zPosition  sequenceNumber
# 1    217368.545745          0               0
# 3    215446.720823          0               0
# 4    224111.298950          0               0
# 6    194063.311595          0               0
# 8    218365.279572          0               0
# ..             ...        ...             ...
# 191  208296.286597          0               0
# 192  210362.191052          0               0
# 195  141478.967336          0               0
# 196  161834.085882          0               0
# 202  199216.363533          0               0
#
# [104 rows x 5 columns]
